# %%
import pandas as pd

# %%
df = pd.read_csv('wuzzuf_data_analyst_jobs_.csv')
df.tail()
# Out:
#                          Job Title                 Company  \
# 120                Cost Accountant            Rehana Group
# 121     Mobile Developer – Flutter                    Daam
# 122                  Equity Trader  Apex Financial Holding
# 123  Quality Assurance Supervisor.          Etisalat Egypt
# 124               Oracle Developer         Blue Bell Egypt
#
#                     Date       Type                  Location  \
# 120   posted 1 month ago  Full Time  Qanater Khairya, Qalubia
# 121   posted 1 month ago  Full Time              Maadi, Cairo
# 122  posted 2 months ago  Full Time              Agouza, Giza
# 123   posted 19 days ago  Full Time              Maadi, Cairo
# 124  posted 2 months ago  Full Time  Bourj Alarab, Alexandria
#
#                                                 Skills  \
# 120  Accounting/Finance, Analyst/Research, Microsof...
# 121  Creative/Design/Art, IT/Software Development, ...
# 122  Accounting/Finance, Equity Trading, Market Ana...
# ...
